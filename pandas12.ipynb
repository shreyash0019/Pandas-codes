# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Shreyas1\\all_data\\Pandas_code\\studentmarks1.csv")
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
#Get First 5 Records of DataFrame by using head()
df.head()
# Out:
#    htno    name  telugu  english  hindi  maths  science  social
# 0   100  Ramesh      50       60     66     98       66      55
# 1   101  Rajesh      45       67     34     67       66      78
# 2   102  Rossum      56       88     56     99       44      77
# 3   103    Raji      56       78     34     56       88      55
# 4   104  Kalyan      51       63     62     93       67      51

# %%
#Get First 3 Records of DataFrame by using head()
df.head(3)
# Out:
#    htno    name  telugu  english  hindi  maths  science  social
# 0   100  Ramesh      50       60     66     98       66      55
# 1   101  Rajesh      45       67     34     67       66      78
# 2   102  Rossum      56       88     56     99       44      77

# %%
df.tail()
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 12   104   Kalyan      51       63     62     93       67      51
# 13   112  shareef      50       63     99     90       76      67
# 14   113     sonu      60       89     98     87       77      68
# 15   114   Rajesh      45       67     77     55       66      46
# 16   115   Rakesh      67       78     88     78       67      49

# %%
df1=df.tail(3)
print(df1,type(df1))
# Out:
#     htno    name  telugu  english  hindi  maths  science  social
# 14   113    sonu      60       89     98     87       77      68
# 15   114  Rajesh      45       67     77     55       66      46
# 16   115  Rakesh      67       78     88     78       67      49 <class 'pandas.core.frame.DataFrame'>

# %%
#Iterate the Rows the from DataFarme
for record in df.iterrows():
    print("---------------------------")
    print(record)
# Out:
# ---------------------------
# (0, htno          100
# name       Ramesh
# telugu         50
# english        60
# hindi          66
# maths          98
# science        66
# social         55
# Name: 0, dtype: object)
# ---------------------------
# (1, htno          101
# name       Rajesh
# telugu         45
# english        67
# hindi          34
# maths          67
# science        66
# social         78
# Name: 1, dtype: object)
# ---------------------------
# (2, htno          102
# name       Rossum
# telugu         56
# english        88
# hindi          56
# maths          99
# science        44
# social         77
# Name: 2, dtype: object)
# ---------------------------
# (3, htno        103
# name       Raji
# telugu       56
# english      78
# hindi        34
# maths        56
# science      88
# social       55
# Name: 3, dtype: object)
# ---------------------------
# (4, htno          104
# name       Kalyan
# telugu         51
# english        63
# hindi          62
# ...

# %%
x=df.shape
print("Number of Rows=",x[0])
print("Number of Cols=",x[1])
# Out:
# Number of Rows= 17
# Number of Cols= 8

# %%
df.describe()
# Out:
#              htno     telugu    english      hindi      maths    science  \
# count   17.000000  17.000000  17.000000  17.000000  17.000000  17.000000
# mean   107.294118  54.000000  70.705882  65.764706  82.235294  69.588235
# std      4.687279   7.141428  11.671358  20.504662  13.917298  14.339887
# min    100.000000  45.000000  48.000000  34.000000  55.000000  44.000000
# 25%    104.000000  50.000000  63.000000  56.000000  76.000000  66.000000
# 50%    107.000000  53.000000  67.000000  64.000000  87.000000  67.000000
# 75%    111.000000  56.000000  78.000000  77.000000  93.000000  77.000000
# max    115.000000  67.000000  89.000000  99.000000  99.000000  98.000000
#
#           social
# count  17.000000
# mean   59.882353
# std    14.696438
# min    35.000000
# 25%    49.000000
# 50%    55.000000
# 75%    73.000000
# max    88.000000

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
df[2:13]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51

# %%
#Apply Indexing on DataFrame---DataFrameObject[StartIndex:EndIndex:Step]
df[12:13]
# Out:
#     htno    name  telugu  english  hindi  maths  science  social
# 12   104  Kalyan      51       63     62     93       67      51

# %%
#Get the records from 10 to 13 
df[10:14]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# 13   112  shareef      50       63     99     90       76      67

# %%
#Get the records from 10 to 13 in reverse Order
df[10:14][::-1]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 13   112  shareef      50       63     99     90       76      67
# 12   104   Kalyan      51       63     62     93       67      51
# 11   111   Ritchi      66       68     64     76       98      75
# 10   110    Biswa      66       48     86     95       48      47

# %%
df[13:9:-1]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 13   112  shareef      50       63     99     90       76      67
# 12   104   Kalyan      51       63     62     93       67      51
# 11   111   Ritchi      66       68     64     76       98      75
# 10   110    Biswa      66       48     86     95       48      47

# %%
#get  alternative records
df[::2]
# Out:
#     htno    name  telugu  english  hindi  maths  science  social
# 0    100  Ramesh      50       60     66     98       66      55
# 2    102  Rossum      56       88     56     99       44      77
# 4    104  Kalyan      51       63     62     93       67      51
# 6    106  Kambli      53       81     59     92       48      73
# 8    108  Ganesh      53       62     76     88       76      35
# 10   110   Biswa      66       48     86     95       48      47
# 12   104  Kalyan      51       63     62     93       67      51
# 14   113    sonu      60       89     98     87       77      68
# 16   115  Rakesh      67       78     88     78       67      49

# %%
#get  alternative records from Index 1
df[1::2]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 1    101   Rajesh      45       67     34     67       66      78
# 3    103     Raji      56       78     34     56       88      55
# 5    105  Karthik      48       62     39     68       65      88
# 7    107  Praveen      46       88     74     86       78      45
# 9    109     Nags      55       77     44     77       86      58
# 11   111   Ritchi      66       68     64     76       98      75
# 13   112  shareef      50       63     99     90       76      67
# 15   114   Rajesh      45       67     77     55       66      46

# %%
#Get the Names from DataFrame
df["name"]
# Out:
# 0      Ramesh
# 1      Rajesh
# 2      Rossum
# 3        Raji
# 4      Kalyan
# 5     Karthik
# 6      Kambli
# 7     Praveen
# 8      Ganesh
# 9        Nags
# 10      Biswa
# 11     Ritchi
# 12     Kalyan
# 13    shareef
# 14       sonu
# 15     Rajesh
# 16     Rakesh
# Name: name, dtype: object

# %%
#Get the Name and science Marks
df[['name','science']]
# Out:
#        name  science
# 0    Ramesh       66
# 1    Rajesh       66
# 2    Rossum       44
# 3      Raji       88
# 4    Kalyan       67
# 5   Karthik       65
# 6    Kambli       48
# 7   Praveen       78
# 8    Ganesh       76
# 9      Nags       86
# 10    Biswa       48
# 11   Ritchi       98
# 12   Kalyan       67
# 13  shareef       76
# 14     sonu       77
# 15   Rajesh       66
# 16   Rakesh       67

# %%
#Get the Htno , names and english marks of Record no 7
df[['htno','name','english']][7:8]
# Out:
#    htno     name  english
# 7   107  Praveen       88

# %%
#Get the 7th Record Values
df[7:8]
# Out:
#    htno     name  telugu  english  hindi  maths  science  social
# 7   107  Praveen      46       88     74     86       78      45

# %%
#Get the 7th Record  related name
df[7:8][["name","htno"]]
# Out:
#       name  htno
# 7  Praveen   107
