# %%
#sorting the data of dataframe
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Shreyas1\\all_data\\Pandas_code\\studentmarks1.csv")
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
df["total"]=df["telugu"]+df["hindi"]+df["english"]+df["maths"]+df["science"]+df["social"]

# %%
print (df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
df['Percent']=df["telugu"]+df["hindi"]+df["english"]+df["maths"]+df["science"]+df["social"]//6
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  Avg  \
# 0    100   Ramesh      50       60     66     98       66      55    395  349
# 1    101   Rajesh      45       67     34     67       66      78    357  292
# 2    102   Rossum      56       88     56     99       44      77    420  355
# 3    103     Raji      56       78     34     56       88      55    367  321
# 4    104   Kalyan      51       63     62     93       67      51    387  344
# 5    105  Karthik      48       62     39     68       65      88    370  296
# 6    106   Kambli      53       81     59     92       48      73    406  345
# 7    107  Praveen      46       88     74     86       78      45    417  379
# 8    108   Ganesh      53       62     76     88       76      35    390  360
# 9    109     Nags      55       77     44     77       86      58    397  348
# 10   110    Biswa      66       48     86     95       48      47    390  350
# ...

# %%
#Syntax:  dataframeobj.sort_values(["colname"],inplace=True)
df.sort_values(["total"])
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total  Avg  \
# 15   114   Rajesh      45       67     77     55       66      46    356  317
# 1    101   Rajesh      45       67     34     67       66      78    357  292
# 3    103     Raji      56       78     34     56       88      55    367  321
# 5    105  Karthik      48       62     39     68       65      88    370  296
# 12   104   Kalyan      51       63     62     93       67      51    387  344
# 4    104   Kalyan      51       63     62     93       67      51    387  344
# 8    108   Ganesh      53       62     76     88       76      35    390  360
# 10   110    Biswa      66       48     86     95       48      47    390  350
# 0    100   Ramesh      50       60     66     98       66      55    395  349
# 9    109     Nags      55       77     44     77       86      58    397  348
# 6    106   Kambli      53       81     59     92       48      73    406  345
# ...

# %%
df.drop(columns=['Avg','Percentage','Percent'], inplace= True)
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total
# 0    100   Ramesh      50       60     66     98       66      55    395
# 1    101   Rajesh      45       67     34     67       66      78    357
# 2    102   Rossum      56       88     56     99       44      77    420
# 3    103     Raji      56       78     34     56       88      55    367
# 4    104   Kalyan      51       63     62     93       67      51    387
# 5    105  Karthik      48       62     39     68       65      88    370
# 6    106   Kambli      53       81     59     92       48      73    406
# 7    107  Praveen      46       88     74     86       78      45    417
# 8    108   Ganesh      53       62     76     88       76      35    390
# 9    109     Nags      55       77     44     77       86      58    397
# 10   110    Biswa      66       48     86     95       48      47    390
# 11   111   Ritchi      66       68     64     76       98      75    447
# ...

# %%
#Get 5 Topper based on Total
df.tail()
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total
# 12   104   Kalyan      51       63     62     93       67      51    387
# 13   112  shareef      50       63     99     90       76      67    445
# 14   113     sonu      60       89     98     87       77      68    479
# 15   114   Rajesh      45       67     77     55       66      46    356
# 16   115   Rakesh      67       78     88     78       67      49    427

# %%
#Get 5 Topper based on Total
df.tail()[::-1]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total
# 16   115   Rakesh      67       78     88     78       67      49    427
# 15   114   Rajesh      45       67     77     55       66      46    356
# 14   113     sonu      60       89     98     87       77      68    479
# 13   112  shareef      50       63     99     90       76      67    445
# 12   104   Kalyan      51       63     62     93       67      51    387

# %%
for record in df.tail()[::-1].iterrows():
    print(record)
    print("-------------------------------")
# Out:
# (16, htno          115
# name       Rakesh
# telugu         67
# english        78
# hindi          88
# maths          78
# science        67
# social         49
# total         427
# Name: 16, dtype: object)
# -------------------------------
# (15, htno          114
# name       Rajesh
# telugu         45
# english        67
# hindi          77
# maths          55
# science        66
# social         46
# total         356
# Name: 15, dtype: object)
# -------------------------------
# (14, htno        113
# name       sonu
# telugu       60
# english      89
# hindi        98
# maths        87
# science      77
# social       68
# total       479
# Name: 14, dtype: object)
# -------------------------------
# (13, htno           112
# name       shareef
# telugu          50
# english         63
# hindi           99
# maths           90
# science         76
# social          67
# total          445
# Name: 13, dtype: object)
# -------------------------------
# (12, htno          104
# ...

# %%
#Syntax:  dataframeobj.sort_values(["colname"],ascending=False,inplace=True)
df.sort_values(["total"],ascending=False,inplace=True)

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total
# 14   113     sonu      60       89     98     87       77      68    479
# 11   111   Ritchi      66       68     64     76       98      75    447
# 13   112  shareef      50       63     99     90       76      67    445
# 16   115   Rakesh      67       78     88     78       67      49    427
# 2    102   Rossum      56       88     56     99       44      77    420
# 7    107  Praveen      46       88     74     86       78      45    417
# 6    106   Kambli      53       81     59     92       48      73    406
# 9    109     Nags      55       77     44     77       86      58    397
# 0    100   Ramesh      50       60     66     98       66      55    395
# 10   110    Biswa      66       48     86     95       48      47    390
# 8    108   Ganesh      53       62     76     88       76      35    390
# 12   104   Kalyan      51       63     62     93       67      51    387
# ...

# %%
for i in df['name']:
    print(i.upper())
# Out:
# SONU
# RITCHI
# SHAREEF
# RAKESH
# ROSSUM
# PRAVEEN
# KAMBLI
# NAGS
# RAMESH
# BISWA
# GANESH
# KALYAN
# KALYAN
# KARTHIK
# RAJI
# RAJESH
# RAJESH

# %%
df.loc[::,["name"]]
# Out:
#        name
# 14     sonu
# 11   Ritchi
# 13  shareef
# 16   Rakesh
# 2    Rossum
# 7   Praveen
# 6    Kambli
# 9      Nags
# 0    Ramesh
# 10    Biswa
# 8    Ganesh
# 12   Kalyan
# 4    Kalyan
# 5   Karthik
# 3      Raji
# 1    Rajesh
# 15   Rajesh

# %%
df.loc[::,["hindi"]]
# Out:
#     hindi
# 14     98
# 11     64
# 13     99
# 16     88
# 2      56
# 7      74
# 6      59
# 9      44
# 0      66
# 10     86
# 8      76
# 12     62
# 4      62
# 5      39
# 3      34
# 1      34
# 15     77

# %%
df.loc[3:3,"hindi"]
# Out:
# 3    34
# Name: hindi, dtype: int64

# %%
df.loc[3:3,"hindi"]=df.loc[3:3,"hindi"]+10

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total
# 14   113     sonu      60       89     98     87       77      68    479
# 11   111   Ritchi      66       68     64     76       98      75    447
# 13   112  shareef      50       63     99     90       76      67    445
# 16   115   Rakesh      67       78     88     78       67      49    427
# 2    102   Rossum      56       88     56     99       44      77    420
# 7    107  Praveen      46       88     74     86       78      45    417
# 6    106   Kambli      53       81     59     92       48      73    406
# 9    109     Nags      55       77     44     77       86      58    397
# 0    100   Ramesh      50       60     66     98       66      55    395
# 10   110    Biswa      66       48     86     95       48      47    390
# 8    108   Ganesh      53       62     76     88       76      35    390
# 12   104   Kalyan      51       63     62     93       67      51    387
# ...

# %%
df.loc[8:4,"hindi"]
# Out:
# 8     76
# 12    62
# 4     62
# Name: hindi, dtype: int64

# %%
df.loc[12::2,"name"]
# Out:
# 12     Kalyan
# 5     Karthik
# 1      Rajesh
# Name: name, dtype: object

# %%
df.loc[12:12,"name"]=df.loc[12:12,"name"]="Soo"
print (df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social  total
# 14   113     sonu      60       89     98     87       77      68    479
# 11   111   Ritchi      66       68     64     76       98      75    447
# 13   112  shareef      50       63     99     90       76      67    445
# 16   115   Rakesh      67       78     88     78       67      49    427
# 2    102   Rossum      56       88     56     99       44      77    420
# 7    107  Praveen      46       88     74     86       78      45    417
# 6    106   Kambli      53       81     59     92       48      73    406
# 9    109     Nags      55       77     44     77       86      58    397
# 0    100   Ramesh      50       60     66     98       66      55    395
# 10   110    Biswa      66       48     86     95       48      47    390
# 8    108   Ganesh      53       62     76     88       76      35    390
# 12   104      Soo      51       63     62     93       67      51    387
# ...

# %%
df.loc[12:12,"name"]
# Out:
# 12    Soo
# Name: name, dtype: object
